# %% [markdown]
# # LSTM

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import math
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # Set Seed

# %%
random.seed(10)

# %% [markdown]
# # Load Data

# %%
#agg_data_monthly = pd.read_csv("aggregate_data_daily.csv", parse_dates=True)
#agg_data_monthly['date'] = pd.to_datetime(agg_data_monthly.date).dt.strftime("%Y-%m")
#agg_data_monthly.sort_values(by='date',ascending=False)
#agg_data_monthly = agg_data_monthly.groupby(["date"]).mean()
#agg_data_monthly.index = pd.DatetimeIndex(agg_data_monthly.index)

# %%
df = pd.read_csv('aggregate_data_daily.csv')
df1 = df['close']
df1
# Out:
# 0       131288.958237
# 1       131832.877280
# 2       129468.922827
# 3       129249.723173
# 4       127985.717387
#             ...
# 1764    257670.968933
# 1765    259022.745291
# 1766    258462.879837
# 1767    259788.447905
# 1768    260920.830000
# Name: close, Length: 1769, dtype: float64

# %% [markdown]
# ### Monthly

# %%
df1_max = max(df['close'])
df1_min = min(df['close'])

# %% [markdown]
# # Data Preprocessing

# %%
scaler = MinMaxScaler(feature_range = (0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
training_size=int(len(df1)*0.8)
test_size = len(df1) - training_size
train_data, test_data = df1[0:training_size,:], df1[training_size:len(df1),:1]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i+time_step, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# # Train/Test Split

# %%
time_step=100
X_train, y_train = create_dataset(train_data, time_step)
X_train2, y_train2 = X_train, y_train
X_test, y_test = create_dataset(test_data, time_step)
X_test2, y_test2 = X_test, y_test

# %%
X_train=X_train.reshape(X_train.shape[0], X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0], X_test.shape[1],1)

# %%
X_train.shape[1]
# Out:
# 100

# %% [markdown]
# # Model

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(64, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.8))  # add a dropout layer with rate 0.8
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.8))  # add a dropout layer with rate 0.8
model.add(Dense(1, activation='relu'))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 21,121
# Trainable params: 21,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=20, batch_size=64, shuffle=False)
# Out:
# Epoch 1/20
# 21/21 [==============================] - 3s 39ms/step - loss: 0.0570
# Epoch 2/20
# 21/21 [==============================] - 1s 35ms/step - loss: 0.0375
# Epoch 3/20
# 21/21 [==============================] - 1s 34ms/step - loss: 0.0309
# Epoch 4/20
# 21/21 [==============================] - 1s 36ms/step - loss: 0.0236
# Epoch 5/20
# 21/21 [==============================] - 1s 37ms/step - loss: 0.0198
# Epoch 6/20
# 21/21 [==============================] - 1s 38ms/step - loss: 0.0183
# Epoch 7/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0173
# Epoch 8/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0152
# Epoch 9/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0154
# Epoch 10/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0149
# Epoch 11/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0147
# Epoch 12/20
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0121
# Epoch 13/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0124
# Epoch 14/20
# 21/21 [==============================] - 1s 37ms/step - loss: 0.0120
# Epoch 15/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0109
# Epoch 16/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0110
# Epoch 17/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0105
# Epoch 18/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0108
# Epoch 19/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0096
# Epoch 20/20
# 21/21 [==============================] - 1s 39ms/step - loss: 0.0096

# %% [markdown]
# # Prediction

# %%
test_predict = model.predict(X_test)
# Out:
# 8/8 [==============================] - 1s 10ms/step

# %%
print(f'MSE {mean_squared_error(y_test2, test_predict)}')
print(f'R2 {r2_score(y_test2, test_predict)}')
print(f'MAE {math.sqrt(mean_squared_error(y_test2, test_predict))}')
# Out:
# MSE 0.023333751669466676
# R2 -2.812279628640711
# MAE 0.15275389248548357

# %%
test_predict= scaler.inverse_transform(test_predict)
train_predict = model.predict(X_train)
train_predict=scaler.inverse_transform(train_predict)
# Out:
# 42/42 [==============================] - 0s 10ms/step

# %%
train_predict
# Out:
# array([[134127.39],
#        [134580.12],
#        [134611.94],
#        ...,
#        [212288.97],
#        [212522.36],
#        [213182.52]], dtype=float32)

# %%
y_test2 = (y_test * (df1_max - df1_min)) + df1_min
y_test2
# Out:
# array([270935.22486487, 271628.08      , 269655.11689008, 267660.90506667,
#        269341.54959459, 271163.46847222, 271170.41324324, 271007.99291553,
#        269618.15898123, 268280.13162162, 267585.96607629, 265818.29182306,
#        270513.56345109, 270177.32613333, 271686.5956044 , 271663.81854396,
#        273954.55797297, 275275.28973333, 276880.45581081, 276188.84919137,
#        272373.80831099, 270379.49180108, 270737.04773333, 268079.85586667,
#        270093.60748663, 271970.71644022, 269055.14931129, 267922.54609164,
#        270368.14373333, 271971.74493333, 271131.4916442 , 272539.5225    ,
#        273363.82024169, 274988.58898072, 274163.25906516, 272413.5108871 ,
#        273655.00969945, 275861.51321526, 275432.58355795, 274772.47472222,
#        271065.8712    , 265851.40666667, 265490.58619303, 266841.30407609,
#        264790.60910543, 261289.85786667, 258941.57754011, 260395.37700535,
#        260326.43342246, 262209.90733333, 262477.60756757, 264787.58946667,
#        262589.72173333, 262516.21933333, 261919.90413333, 257824.8236    ,
#        250021.20200535, 254572.7942623 , 255997.6648    , 258346.17272727,
#        256899.88967391, 257552.91613333, 260598.2572    , 260982.55066667,
#        261056.17252011, 264104.044     , 266762.3348    , 267743.7724    ,
#        270019.34906667, 268321.1704    , 269608.0692    , 271411.6416    ,
#        272065.87345845, 273056.44769022, 272941.45409836, 272747.7964    ,
#        273779.02486413, 272884.06186667, 268360.13702703, 266666.90525606,
#        263111.66911765, 257394.06546667, 255568.72693333, 253007.5572    ,
#        257181.46586021, 257815.06256757, 260661.86470588, 263878.09579946,
#        263176.28431635, 261891.75806452, 258380.86286863, 257475.10986667,
#        253701.92746667, 255526.01533333, 259670.78866667, 259131.00187166,
#        257330.5101626 , 256401.55173333, 253064.11930295, 256159.48314917,
#        246763.41733333, 249439.67466667, 248732.01276882, 247433.44853333,
#        246137.3452    , 239767.72493333, 232054.62649007, 231021.9716    ,
#        235871.77386667, 242531.0368    , 241765.68890374, 242222.50640327,
#        244231.94304813, 246521.85650406, 252480.0804    , 251091.22938005,
#        247662.23347222, 249602.93753541, 248249.26417112, 246906.0150134 ,
#        245119.30653333, 247802.44008264, 250636.12479675, 250990.87173333,
#        252383.4773842 , 257239.8016    , 259817.70643432, 258414.35147849,
#        258248.80712329, 258948.98482385, 259795.67562674, 257272.32018717,
#        257450.47179487, 253149.91147541, 255616.87613333, 254892.62043597,
#        251723.23077957, 254792.68016997, 252332.78756684, 253962.28968927,
#        255839.57866848, 251508.9228    , 248868.17144772, 246473.07797297,
#        239157.38293333, 236735.6       , 237949.88310992, 235004.6094086 ,
#        230609.33404826, 232405.67735849, 230783.83672087, 233148.66852861,
#        236140.60613333, 231000.73696237, 234802.57743243, 237334.0092246 ,
#        234764.85502717, 233221.25528455, 232239.80569106, 236877.87105263,
#        241390.27589041, 241909.95923913, 240486.86260054, 239169.80094851,
#        238268.8152815 , 234924.30512129, 232116.63203753, 232497.6596    ,
#        231859.98773585, 230983.70482574, 226703.83096515, 227020.89663979,
#        227087.04301075, 225304.62198391, 220748.5188    , 227964.4       ,
#        230841.46917404, 229694.29400545, 229941.21202703, 229928.04825073,
#        229573.27177419, 232187.43486486, 234962.12773333, 236586.38026667,
#        239821.12125668, 240215.68950954, 240619.65735294, 240017.3556    ,
#        239847.65225352, 238669.96353887, 239344.8489071 , 242263.78700565,
#        242993.66040462, 245520.71035422, 246076.8502809 , 248339.36420613,
#        247724.94716981, 246260.75458333, 246721.72676056, 250932.16306818,
#        253051.27038043, 255670.47906667, 257256.20306667, 256234.5696    ,
#        256995.04371658, 258592.60121951, 258628.0912    , 258778.91276882,
#        260724.56729107, 260284.28075843, 262797.55955679, 264512.19530831,
#        264147.59306667, 262903.568     , 258459.64097035, 258195.87741935,
#        261829.45973451, 262075.05989305, 261408.20534759, 261117.71266846,
#        260993.70819892, 262246.50467914, 265639.58061497, 268168.30588235,
#        268314.23586667, 269529.97413333, 269765.89177898, 269973.40588235,
#        265951.60900538, 264711.21946667, 268331.02210243, 265887.0172    ,
#        263946.68186667, 260826.6036    , 255205.84253333, 254763.4256    ,
#        254297.3484    , 253503.95723861, 254579.0504    , 253991.50186667,
#        256590.02053333, 258034.27820856, 256941.0052139 , 255399.84193548,
#        254314.474     , 252915.43763441, 252732.5208    , 255376.81965241,
#        254610.58026667, 257670.96893333, 259022.74529086, 258462.87983651,
#        259788.44790503])

# %%
print(f'MSE {mean_squared_error(y_test2, test_predict)}')
print(f'R2 {r2_score(y_test2, test_predict)}')
print(f'MAE {math.sqrt(mean_squared_error(y_test2, test_predict))}')
# Out:
# MSE 672766454.4304233
# R2 -2.81227818419335
# MAE 25937.741891506732

# %%
look_back = 100

trainPredictPlot = np.empty_like(df1)
trainPredictPlot[:,:] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

testPredictPlot = np.empty_like(df1)
testPredictPlot[:,:] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict

# %%
plt.figure(figsize=(20,8))
plt.rcParams.update({'font.size': 22})
plt.plot(scaler.inverse_transform(df1), label = 'Main Dataset')
plt.plot(trainPredictPlot, label = 'Train Dataset')
plt.plot(testPredictPlot, label = 'Test Dataset')
plt.legend()
